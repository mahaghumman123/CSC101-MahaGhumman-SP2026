# %% [markdown]
# <a href="https://colab.research.google.com/github/mahaghumman123/CSC101-MahaGhumman-SP2026/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!")
a=3
b=6
print(a,b)
name="Maha Ghumman"
print("name:",name)
height=12.2
print(type(height))
first="home"
second="work"
print(first+""+second)
user_name=input("enter your name:")
print("welcome,",user_name)
x=12
y=3
print("sum:",x+y)
print("product:",x*y)
a=5
b=15
print("remainder:",a%b)
print("exponent:",a**b)
roll_number=42
print(f"your roll number is {roll_number}")
# Out:
# hello world!
# 3 6
# name: Maha Ghumman
# <class 'float'>
# homework
# enter your name:maha
# welcome, maha
# sum: 15
# product: 36
# remainder: 5
# exponent: 30517578125
# your roll number is 42

# %%
name = input("What is your name? ")
print("Hello, " + name + "! Welcome to your first interactive lab.")
city=input("where are you from?")
print(city+"sounds like a great place!")
x= input("Enter first number: ")
y= input("Enter second number: ")
sum = int(a) + int(y)
print("The sum is:", sum)
# Out:
# What is your name? maha
# Hello, maha! Welcome to your first interactive lab.
# where are you from?bahawalpur
# bahawalpursounds like a great place!
# Enter first number: 6
# Enter second number: 7
# The sum is: 12
